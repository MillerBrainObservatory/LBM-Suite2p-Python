# %% [markdown]
# # Post-Processing

# %%
from pathlib import Path
import numpy as np
import lbm_suite2p_python as lsp

# %% [markdown]
# DF/F
#
# By default, the pipeline uses a default For each calcium trace:
#
# - Computes baseline signal (F0) as a rolling percentile filter (percentile_filter) across a sliding window.
# - Ensures F0 never goes below 1% of the median.
# - Computes $\Delta F/F$ as $(F - F_0)/F_0$.

# %%
suite2p_output_path = Path(r"E:\W1_USER_DATA\demo-user\mrois-zarr-zreg")
