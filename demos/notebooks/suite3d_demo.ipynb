# %% [markdown]
# # General Examples
#
# A place to keep processing or other functionality that may lie outside of the standard pipeline.

# %%
from pathlib import Path
import os
import numpy as np
from copy import deepcopy
import traceback

import fastplotlib as fpl
import matplotlib.pyplot as plt

import dask.array as da
import tifffile

import suite2p
from suite2p.io import BinaryFile, BinaryFileCombined

from suite3d.job import Job
from suite3d import ui
from suite3d import io
from suite3d.job import Job
from suite3d import io

import mbo_utilities as mbo
import lbm_suite2p_python as lsp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       4 from copy import deepcopy
#       5 import traceback
# ----> 7 import fastplotlib as fpl
#       8 import matplotlib.pyplot as plt
#      10 import dask.array as da
#
# ModuleNotFoundError: No module named 'fastplotlib'

# %%
fpath = r""
